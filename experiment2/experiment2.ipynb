# %% [markdown]
# # Recognizing Traffic Signs
# The goal of this project is to build a model capable of determining the type of traffic sign that is displayed in an image captured under different real-life conditions and showing obstructions, poor lighting, or even the sign being far away from the camera. We provide you with labeled images already splited in three files (tran/val/test) and a predefined list of signs to recognise.

# %%
# # Download and unzip
dataroot = "../dataroot/"
# !mkdir dataroot 
# !wget -P dataroot https://raw.githubusercontent.com/emmanueliarussi/DataScienceCapstone/master/3_MidtermProjects/ProjectRTS/data/data_1.zip
# !wget -P dataroot https://raw.githubusercontent.com/emmanueliarussi/DataScienceCapstone/master/3_MidtermProjects/ProjectRTS/data/data_2.zip
# !wget -P dataroot https://raw.githubusercontent.com/emmanueliarussi/DataScienceCapstone/master/3_MidtermProjects/ProjectRTS/data/data_3.zip

# %%
# # Unzip
# import zipfile
# with zipfile.ZipFile(dataroot+"data_1.zip","r") as zip_ref:
#     zip_ref.extractall(dataroot)
# with zipfile.ZipFile(dataroot+"data_2.zip","r") as zip_ref:
#     zip_ref.extractall(dataroot)
# with zipfile.ZipFile(dataroot+"data_3.zip","r") as zip_ref:
#     zip_ref.extractall(dataroot)

# %%
# Load sign names
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/emmanueliarussi/DataScienceCapstone/master/3_MidtermProjects/ProjectRTS/data/signnames.csv")
signnames = pd.Series(df.SignName.values,index=df.ClassId).to_dict()
signnames
# Out:
# {0: 'Speed limit (20km/h)',
#  1: 'Speed limit (30km/h)',
#  2: 'Speed limit (50km/h)',
#  3: 'Speed limit (60km/h)',
#  4: 'Speed limit (70km/h)',
#  5: 'Speed limit (80km/h)',
#  6: 'End of speed limit (80km/h)',
#  7: 'Speed limit (100km/h)',
#  8: 'Speed limit (120km/h)',
#  9: 'No passing',
#  10: 'No passing for vehicles over 3.5 metric tons',
#  11: 'Right-of-way at the next intersection',
#  12: 'Priority road',
#  13: 'Yield',
#  14: 'Stop',
#  15: 'No vehicles',
#  16: 'Vehicles over 3.5 metric tons prohibited',
#  17: 'No entry',
#  18: 'General caution',
#  19: 'Dangerous curve to the left',
#  20: 'Dangerous curve to the right',
#  21: 'Double curve',
#  22: 'Bumpy road',
#  23: 'Slippery road',
#  24: 'Road narrows on the right',
#  25: 'Road work',
#  26: 'Traffic signals',
#  27: 'Pedestrians',
#  28: 'Children crossing',
#  29: 'Bicycles crossing',
#  30: 'Beware of ice/snow',
#  31: 'Wild animals crossing',
#  32: 'End of all speed and passing limits',
#  33: 'Turn right ahead',
#  34: 'Turn left ahead',
#  35: 'Ahead only',
#  36: 'Go straight or right',
#  37: 'Go straight or left',
#  38: 'Keep right',
#  39: 'Keep left',
#  40: 'Roundabout mandatory',
#  41: 'End of no passing',
#  42: 'End of no passing by vehicles over 3.5 metric tons'}

# %%
df.to_csv("sign_names.csv")

# %%
# Load images
import pickle
signimages = pickle.load( open( dataroot+"train.p", "rb" ) )

# %%
# Preview image
import matplotlib.pyplot as plt
import numpy as np
# import cv2

inx = 20123
plt.imshow(signimages['features'][inx])
print("The image shows a {} sign".format(signnames[signimages['labels'][inx]]))
# Out:
# The image shows a Turn left ahead sign

# %%
import tensorflow as tf
import tensorflow_addons as tfa
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import numpy as np
import platform
import datetime
import os
import math
import random
from toolz import pipe

from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# c:\users\kitthekat\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\client\session.py:1751: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '

# %%
# !rd /s /q logs

# %%
train = signimages
with open( dataroot+"test.p", "rb" ) as fp:
    test = pickle.load(fp)
with open( dataroot+"valid.p", "rb" ) as fp:
    valid = pickle.load(fp)

# %% [markdown]
# ### Preprocessing

# %%
def format_example(image):
    """
    Converts image color range to 0:1, consistent size
    """
    return tf.image.resize(tf.cast(image, tf.float32)/255, [32, 32])

# %%
def convert_to_tf_dataset(raw_data):
    """
    Converts raw images and labels into a tensorflow dataset
    """
    return tf.data.Dataset.from_tensor_slices(
                (
                    list(map(format_example, raw_data['features'])), 
                    tf.cast(raw_data['labels'], tf.int32)
                )
            )

# %% [markdown]
# #### Convert datasets to Tensorflow datasets

# %%
train, test, valid = tuple(map(convert_to_tf_dataset, [train, test, valid]))

# %%
type(train)
# Out:
# tensorflow.python.data.ops.dataset_ops.TensorSliceDataset

# %% [markdown]
# ##### Confirm TF conversion success by previewing image/label

# %%
first_image, first_label = list(train.take(1))[0]

# %%
signnames[first_label.numpy()]
# Out:
# 'End of no passing'

# %%
plt.imshow(first_image.numpy())

# %% [markdown]
# #### Augment Dataset

# %%
def random_image_flip(image: tf.Tensor) -> tf.Tensor:
    """
    Randomly flips an image left/right
    """
    return tf.image.random_flip_left_right(image)

def random_color_change(image: tf.Tensor) -> tf.Tensor:
    """
    Randomly adjusts brightness, contrast, or saturation in an image. Does not adjust
    hue
    """
    return tf.clip_by_value(
                tf.image.random_contrast(
                    tf.image.random_brightness(
                        tf.image.random_saturation(image, lower=.75, upper=1.25), 
                        .05
                    ), 
                    lower=.75,
                    upper=1
                ), 
                clip_value_min=0, 
                clip_value_max=1
            )

def random_image_rotation(image: tf.Tensor) -> tf.Tensor:
    """
    Randomly rotates and image between 30 and -30 degrees
    """
    return tfa.image.rotate(image, tf.random.uniform(shape=[], minval=-.2, maxval=.2, dtype=tf.float32))

def augment_image(image: tf.Tensor, label: tf.Tensor) -> tf.Tensor:
    """
    Performs random augmentation of image
    """
    return pipe(image,
               random_image_flip,
               random_color_change,
               random_image_rotation), label

# %%
plt.imshow(augment_image(first_image.numpy(), 'test')[0])
# Out:
# c:\users\kitthekat\appdata\local\programs\python\python38\lib\site-packages\tensorflow_addons\image\transform_ops.py:142: UserWarning: fill_value is not supported and is always 0 for TensorFlow < 2.4.0.
#   warnings.warn(

# %%
plt.imshow(augment_image(first_image.numpy(), 'test')[0])

# %%
augmented_data = train.map(augment_image)
# Out:
# c:\users\kitthekat\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\autograph\impl\api.py:493: UserWarning: fill_value is not supported and is always 0 for TensorFlow < 2.4.0.
#   return py_builtins.overload_of(f)(*args)

# %%
train = train.concatenate(augmented_data)

# %% [markdown]
# #### Batching

# %%
shuffled_train = train.shuffle(len(train)).batch(32).prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
shuffled_test = test.batch(32)

# %%
batches = tfds.as_numpy(shuffled_test)

# %%
for batch in batches:
    image_batch, label_batch = batch
    print('Label batch shape:', label_batch.shape, '\n')
    print('Image batch shape:', image_batch.shape, '\n')
    print('Label batch:', label_batch, '\n')
    
    for batch_item_index in range(len(image_batch)):
        print(image_batch[batch_item_index].shape)
        print('First batch image:', image_batch[batch_item_index], '\n')
        plt.imshow(image_batch[batch_item_index])
        plt.show()
        # Break to shorten the output.
        break
    # Break to shorten the output.
    break
# Out:
# Label batch shape: (32,)
#
# Image batch shape: (32, 32, 32, 3)
#
# Label batch: [16  1 38 33 11 38 18 12 25 35 12  7 23  7  4  9 21 20 27 38  4 33  9  3
#   1 11 13 10  9 11  5 17]
#
# (32, 32, 3)
# First batch image: [[[0.45490196 0.54509807 0.68235296]
#   [0.45490196 0.5372549  0.67058825]
#   [0.4627451  0.5411765  0.6745098 ]
#   ...
#   [0.38431373 0.44705883 0.56078434]
#   [0.38039216 0.4745098  0.5764706 ]
#   [0.33333334 0.4117647  0.50980395]]
#
#  [[0.4509804  0.5568628  0.6901961 ]
#   [0.4509804  0.54901963 0.68235296]
#   [0.45882353 0.5529412  0.6862745 ]
#   ...
#   [0.46666667 0.56078434 0.6901961 ]
#   [0.47058824 0.5529412  0.6784314 ]
#   [0.47058824 0.54509807 0.67058825]]
#
#  [[0.45882353 0.5529412  0.68235296]
#   [0.45882353 0.5568628  0.6862745 ]
#   [0.44705883 0.54901963 0.6745098 ]
#   ...
#   [0.47058824 0.5647059  0.7019608 ]
#   [0.47843137 0.5647059  0.7019608 ]
#   [0.47058824 0.56078434 0.69411767]]
#
#  ...
#
#  [[0.45882353 0.5372549  0.654902  ]
#   [0.4509804  0.5254902  0.6431373 ]
#   [0.45882353 0.5294118  0.6431373 ]
#   ...
#   [0.4509804  0.5372549  0.6627451 ]
#   [0.45490196 0.53333336 0.65882355]
#   [0.4627451  0.54509807 0.6745098 ]]
#
#  [[0.45490196 0.53333336 0.6509804 ]
#   [0.44705883 0.5254902  0.65882355]
#   [0.44313726 0.5137255  0.6509804 ]
#   ...
#   [0.44313726 0.5294118  0.654902  ]
#   [0.45882353 0.53333336 0.64705884]
#   [0.4509804  0.54509807 0.654902  ]]
#
#  [[0.4392157  0.5294118  0.654902  ]
#   [0.43137255 0.5254902  0.64705884]
#   [0.46666667 0.5294118  0.64705884]
#   ...
#   [0.4509804  0.5411765  0.654902  ]
#   [0.45882353 0.5411765  0.654902  ]
#   [0.44705883 0.54901963 0.6666667 ]]]

# %% [markdown]
# ### Training

# %% [markdown]
# #### Create Model

# %%
model = tf.keras.models.Sequential()

model.add(
    tf.keras.layers.Convolution2D(
        input_shape=(32, 32, 3),
        filters=64,
        kernel_size=3,
        activation='relu'
    )
)

model.add(
    tf.keras.layers.MaxPooling2D(
        pool_size=(2, 2),
        strides=(2, 2),
        padding='same'
    )
)

model.add(
    tf.keras.layers.Convolution2D(
        filters=64, 
        kernel_size=3, 
        activation='relu'
    )
)

model.add(
    tf.keras.layers.MaxPooling2D(
        pool_size=(2, 2),
        strides=(2, 2),
        padding='same'
    )
)

model.add(
    tf.keras.layers.Convolution2D(
        filters=128, 
        kernel_size=3, 
        activation='relu'
    )
)

model.add(
    tf.keras.layers.MaxPooling2D(
        pool_size=(2, 2),
        strides=(2, 2),
        padding='same'
    )
)

model.add(
    tf.keras.layers.Convolution2D(
        filters=128, 
        kernel_size=3, 
        activation='relu'
    )
)

model.add(
    tf.keras.layers.MaxPooling2D(
        pool_size=(2, 2),
        strides=(2, 2),
        padding='same'
    )
)

model.add(
    tf.keras.layers.Flatten()
)

model.add(
    tf.keras.layers.Dropout(0.5)
)

model.add(
    tf.keras.layers.Dense(
        units=512, 
        activation='relu'
    )
)

model.add(
    tf.keras.layers.Dense(
        units=256, 
        activation='relu'
    )
)

model.add(
    tf.keras.layers.Dense(
        units=len(signnames.keys()), 
        activation='softmax'
    )
)

# %% [markdown]
# ##### Model Summary

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 64)        1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 5, 5, 128)         73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 3, 3, 128)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 1, 1, 128)         147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 43)                11051
# =================================================================
# Total params: 468,587
# Trainable params: 468,587
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(
    model,
    show_shapes=True,
    show_layer_names=True,
)

# %% [markdown]
# #### Compile Model

# %%
adam_optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

model.compile(
    optimizer=adam_optimizer,
    loss=tf.keras.losses.sparse_categorical_crossentropy,
    metrics=['accuracy']
)

# %% [markdown]
# #### Prepare callbacks/tensorboard

# %%
steps_per_epoch = len(shuffled_train) // 32
validation_steps = len(shuffled_test) // 32

# %%
# !rd /s /q "tmp/checkpoints"
# !rd /s /q logs
# Out:
# The system cannot find the file specified.

# %%
# Preparing callbacks.
os.makedirs('logs/fit', exist_ok=True)
tensorboard_log_dir = 'logs/fit/' + datetime.datetime.now().strftime('%Y%m%d-%H%M%S')
tensorboard_callback = tf.keras.callbacks.TensorBoard(
    log_dir=tensorboard_log_dir,
    histogram_freq=1
)

os.makedirs('tmp/checkpoints', exist_ok=True)
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='tmp/checkpoints/weights.{epoch:02d}-{val_loss:.2f}.hdf5'
)

early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    patience=30,
    monitor='val_accuracy'
)

# %%
training_history = model.fit(
    x=shuffled_train.repeat(),
    validation_data=shuffled_test.repeat(),
    epochs=750,
    steps_per_epoch=steps_per_epoch,
    validation_steps=validation_steps,
    callbacks=[
        model_checkpoint_callback,
#         early_stopping_callback,
        tensorboard_callback
    ],
    verbose=1
)
# Out:
# Epoch 1/750
#  1/67 [..............................] - ETA: 0s - loss: 3.7537 - accuracy: 0.0625WARNING:tensorflow:From c:\users\kitthekat\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#  2/67 [..............................] - ETA: 3s - loss: 3.7433 - accuracy: 0.0781WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0040s vs `on_train_batch_end` time: 0.0902s). Check your callbacks.
# 67/67 [==============================] - 1s 11ms/step - loss: 3.5619 - accuracy: 0.0597 - val_loss: 3.5318 - val_accuracy: 0.0391
# Epoch 2/750
# 67/67 [==============================] - 0s 6ms/step - loss: 3.5145 - accuracy: 0.0536 - val_loss: 3.4972 - val_accuracy: 0.0755
# Epoch 3/750
# 67/67 [==============================] - 0s 6ms/step - loss: 3.3638 - accuracy: 0.0933 - val_loss: 3.0890 - val_accuracy: 0.1432
# Epoch 4/750
# 67/67 [==============================] - 0s 6ms/step - loss: 2.8035 - accuracy: 0.1856 - val_loss: 2.4051 - val_accuracy: 0.2578
# Epoch 5/750
# 67/67 [==============================] - 0s 6ms/step - loss: 2.3164 - accuracy: 0.2789 - val_loss: 2.1556 - val_accuracy: 0.3073
# Epoch 6/750
# 67/67 [==============================] - 0s 6ms/step - loss: 2.1379 - accuracy: 0.3083 - val_loss: 1.9925 - val_accuracy: 0.3229
# Epoch 7/750
# 67/67 [==============================] - 0s 6ms/step - loss: 2.0134 - accuracy: 0.3223 - val_loss: 1.9177 - val_accuracy: 0.3542
# Epoch 8/750
# 67/67 [==============================] - 0s 6ms/step - loss: 1.9072 - accuracy: 0.3563 - val_loss: 1.8574 - val_accuracy: 0.3906
# Epoch 9/750
# 67/67 [==============================] - 0s 6ms/step - loss: 1.8645 - accuracy: 0.3671 - val_loss: 1.7036 - val_accuracy: 0.4297
# Epoch 10/750
# 67/67 [==============================] - 0s 6ms/step - loss: 1.7752 - accuracy: 0.3918 - val_loss: 1.6702 - val_accuracy: 0.3958
# Epoch 11/750
# 67/67 [==============================] - 0s 6ms/step - loss: 1.7027 - accuracy: 0.4049 - val_loss: 1.6571 - val_accuracy: 0.4349
# Epoch 12/750
# 67/67 [==============================] - 0s 6ms/step - loss: 1.6868 - accuracy: 0.4277 - val_loss: 1.5671 - val_accuracy: 0.4531
# Epoch 13/750
# 67/67 [==============================] - 0s 6ms/step - loss: 1.6149 - accuracy: 0.4347 - val_loss: 1.4930 - val_accuracy: 0.4766
# Epoch 14/750
# 67/67 [==============================] - 0s 6ms/step - loss: 1.5300 - accuracy: 0.4622 - val_loss: 1.5570 - val_accuracy: 0.4531
# Epoch 15/750
# 67/67 [==============================] - 0s 6ms/step - loss: 1.4913 - accuracy: 0.4893 - val_loss: 1.3904 - val_accuracy: 0.4766
# Epoch 16/750
# 67/67 [==============================] - 0s 6ms/step - loss: 1.4876 - accuracy: 0.4995 - val_loss: 1.3310 - val_accuracy: 0.5156
# Epoch 17/750
# 67/67 [==============================] - 0s 6ms/step - loss: 1.3695 - accuracy: 0.5233 - val_loss: 1.2674 - val_accuracy: 0.6016
# Epoch 18/750
# 67/67 [==============================] - 0s 6ms/step - loss: 1.3313 - accuracy: 0.5271 - val_loss: 1.1689 - val_accuracy: 0.6146
# Epoch 19/750
# 67/67 [==============================] - 0s 6ms/step - loss: 1.2117 - accuracy: 0.5606 - val_loss: 1.0947 - val_accuracy: 0.6146
# Epoch 20/750
# 67/67 [==============================] - 0s 6ms/step - loss: 1.2499 - accuracy: 0.5616 - val_loss: 1.0727 - val_accuracy: 0.6354
# Epoch 21/750
# 67/67 [==============================] - 0s 6ms/step - loss: 1.1687 - accuracy: 0.5788 - val_loss: 1.0107 - val_accuracy: 0.6797
# Epoch 22/750
# 67/67 [==============================] - 0s 6ms/step - loss: 1.1298 - accuracy: 0.5914 - val_loss: 0.9870 - val_accuracy: 0.6641
# Epoch 23/750
# 67/67 [==============================] - 0s 6ms/step - loss: 1.0898 - accuracy: 0.6250 - val_loss: 0.9482 - val_accuracy: 0.6641
# Epoch 24/750
# 67/67 [==============================] - 0s 6ms/step - loss: 1.0228 - accuracy: 0.6544 - val_loss: 0.8227 - val_accuracy: 0.6979
# Epoch 25/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.9553 - accuracy: 0.6772 - val_loss: 0.8298 - val_accuracy: 0.7422
# Epoch 26/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.9709 - accuracy: 0.6469 - val_loss: 0.7595 - val_accuracy: 0.7292
# Epoch 27/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.8920 - accuracy: 0.7010 - val_loss: 0.7612 - val_accuracy: 0.7682
# Epoch 28/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.8475 - accuracy: 0.7043 - val_loss: 0.6694 - val_accuracy: 0.7969
# Epoch 29/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.8750 - accuracy: 0.6912 - val_loss: 0.6428 - val_accuracy: 0.7969
# Epoch 30/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.8083 - accuracy: 0.7257 - val_loss: 0.6274 - val_accuracy: 0.7891
# Epoch 31/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.8118 - accuracy: 0.7276 - val_loss: 0.6075 - val_accuracy: 0.8255
# Epoch 32/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.7483 - accuracy: 0.7472 - val_loss: 0.6318 - val_accuracy: 0.8021
# Epoch 33/750
# 67/67 [==============================] - 7s 103ms/step - loss: 0.7144 - accuracy: 0.7619 - val_loss: 0.5713 - val_accuracy: 0.8229
# Epoch 34/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.6790 - accuracy: 0.7724 - val_loss: 0.5519 - val_accuracy: 0.8255
# Epoch 35/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.6871 - accuracy: 0.7691 - val_loss: 0.4689 - val_accuracy: 0.8542
# Epoch 36/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.6563 - accuracy: 0.7738 - val_loss: 0.5151 - val_accuracy: 0.8438
# Epoch 37/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.6532 - accuracy: 0.7864 - val_loss: 0.5291 - val_accuracy: 0.8464
# Epoch 38/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.6003 - accuracy: 0.7878 - val_loss: 0.4750 - val_accuracy: 0.8646
# Epoch 39/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.6476 - accuracy: 0.7882 - val_loss: 0.4556 - val_accuracy: 0.8542
# Epoch 40/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.5844 - accuracy: 0.7999 - val_loss: 0.4824 - val_accuracy: 0.8333
# Epoch 41/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.5589 - accuracy: 0.8125 - val_loss: 0.4756 - val_accuracy: 0.8438
# Epoch 42/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.5700 - accuracy: 0.8032 - val_loss: 0.4547 - val_accuracy: 0.8646
# Epoch 43/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.5213 - accuracy: 0.8209 - val_loss: 0.4751 - val_accuracy: 0.8438
# Epoch 44/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.5945 - accuracy: 0.8069 - val_loss: 0.3554 - val_accuracy: 0.8958
# Epoch 45/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.5441 - accuracy: 0.8279 - val_loss: 0.4195 - val_accuracy: 0.8802
# Epoch 46/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.4895 - accuracy: 0.8349 - val_loss: 0.4182 - val_accuracy: 0.8542
# Epoch 47/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.5335 - accuracy: 0.8321 - val_loss: 0.3717 - val_accuracy: 0.8880
# Epoch 48/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.5073 - accuracy: 0.8307 - val_loss: 0.3890 - val_accuracy: 0.8776
# Epoch 49/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.4953 - accuracy: 0.8293 - val_loss: 0.3790 - val_accuracy: 0.8672
# Epoch 50/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.4756 - accuracy: 0.8377 - val_loss: 0.3047 - val_accuracy: 0.8828
# Epoch 51/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.4705 - accuracy: 0.8405 - val_loss: 0.4010 - val_accuracy: 0.8854
# Epoch 52/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.4709 - accuracy: 0.8447 - val_loss: 0.3386 - val_accuracy: 0.8984
# Epoch 53/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.4104 - accuracy: 0.8545 - val_loss: 0.3897 - val_accuracy: 0.8620
# Epoch 54/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.4289 - accuracy: 0.8545 - val_loss: 0.3088 - val_accuracy: 0.8880
# Epoch 55/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.4456 - accuracy: 0.8512 - val_loss: 0.3436 - val_accuracy: 0.8958
# Epoch 56/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.4222 - accuracy: 0.8624 - val_loss: 0.4072 - val_accuracy: 0.8542
# Epoch 57/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.4448 - accuracy: 0.8503 - val_loss: 0.3676 - val_accuracy: 0.8698
# Epoch 58/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.4502 - accuracy: 0.8465 - val_loss: 0.3081 - val_accuracy: 0.8958
# Epoch 59/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.4026 - accuracy: 0.8615 - val_loss: 0.3378 - val_accuracy: 0.8880
# Epoch 60/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.3573 - accuracy: 0.8843 - val_loss: 0.3467 - val_accuracy: 0.8880
# Epoch 61/750
# 67/67 [==============================] - 0s 5ms/step - loss: 0.4444 - accuracy: 0.8498 - val_loss: 0.3206 - val_accuracy: 0.8958
# Epoch 62/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.4340 - accuracy: 0.8503 - val_loss: 0.2967 - val_accuracy: 0.9010
# Epoch 63/750
# 67/67 [==============================] - 0s 5ms/step - loss: 0.3895 - accuracy: 0.8680 - val_loss: 0.3055 - val_accuracy: 0.8854
# Epoch 64/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.3927 - accuracy: 0.8727 - val_loss: 0.3252 - val_accuracy: 0.8958
# Epoch 65/750
# 67/67 [==============================] - 7s 102ms/step - loss: 0.3326 - accuracy: 0.8810 - val_loss: 0.3176 - val_accuracy: 0.9141
# Epoch 66/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.3596 - accuracy: 0.8820 - val_loss: 0.3205 - val_accuracy: 0.9115
# Epoch 67/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.3700 - accuracy: 0.8801 - val_loss: 0.2580 - val_accuracy: 0.9141
# Epoch 68/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.3426 - accuracy: 0.8871 - val_loss: 0.3093 - val_accuracy: 0.9089
# Epoch 69/750
# 67/67 [==============================] - 0s 5ms/step - loss: 0.3496 - accuracy: 0.8876 - val_loss: 0.3733 - val_accuracy: 0.8958
# Epoch 70/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.3318 - accuracy: 0.8853 - val_loss: 0.3036 - val_accuracy: 0.9167
# Epoch 71/750
# 67/67 [==============================] - 0s 5ms/step - loss: 0.3653 - accuracy: 0.8815 - val_loss: 0.3449 - val_accuracy: 0.8932
# Epoch 72/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.3470 - accuracy: 0.8792 - val_loss: 0.3260 - val_accuracy: 0.9115
# Epoch 73/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.3593 - accuracy: 0.8764 - val_loss: 0.2648 - val_accuracy: 0.9193
# Epoch 74/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.3306 - accuracy: 0.8885 - val_loss: 0.2895 - val_accuracy: 0.9010
# Epoch 75/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.3343 - accuracy: 0.8941 - val_loss: 0.3166 - val_accuracy: 0.8932
# Epoch 76/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.3414 - accuracy: 0.8853 - val_loss: 0.3093 - val_accuracy: 0.9115
# Epoch 77/750
# 67/67 [==============================] - 0s 5ms/step - loss: 0.3225 - accuracy: 0.8979 - val_loss: 0.2861 - val_accuracy: 0.9141
# Epoch 78/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.3120 - accuracy: 0.8946 - val_loss: 0.3742 - val_accuracy: 0.8854
# Epoch 79/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.3247 - accuracy: 0.8871 - val_loss: 0.2856 - val_accuracy: 0.9062
# Epoch 80/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.3149 - accuracy: 0.8997 - val_loss: 0.2383 - val_accuracy: 0.9115
# Epoch 81/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.3055 - accuracy: 0.9021 - val_loss: 0.2970 - val_accuracy: 0.9193
# Epoch 82/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.3159 - accuracy: 0.8937 - val_loss: 0.2594 - val_accuracy: 0.9089
# Epoch 83/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.3085 - accuracy: 0.8979 - val_loss: 0.3040 - val_accuracy: 0.9036
# Epoch 84/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.3091 - accuracy: 0.9044 - val_loss: 0.3445 - val_accuracy: 0.8932
# Epoch 85/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.3163 - accuracy: 0.8941 - val_loss: 0.3309 - val_accuracy: 0.8984
# Epoch 86/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.3368 - accuracy: 0.8932 - val_loss: 0.3114 - val_accuracy: 0.9115
# Epoch 87/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.3061 - accuracy: 0.8997 - val_loss: 0.2888 - val_accuracy: 0.9062
# Epoch 88/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2809 - accuracy: 0.9044 - val_loss: 0.2691 - val_accuracy: 0.9193
# Epoch 89/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.3216 - accuracy: 0.8965 - val_loss: 0.2658 - val_accuracy: 0.9193
# Epoch 90/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2957 - accuracy: 0.8969 - val_loss: 0.2495 - val_accuracy: 0.9062
# Epoch 91/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2655 - accuracy: 0.9142 - val_loss: 0.2784 - val_accuracy: 0.9167
# Epoch 92/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2607 - accuracy: 0.9198 - val_loss: 0.3187 - val_accuracy: 0.9193
# Epoch 93/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2690 - accuracy: 0.9044 - val_loss: 0.2938 - val_accuracy: 0.9167
# Epoch 94/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2881 - accuracy: 0.9109 - val_loss: 0.2652 - val_accuracy: 0.9297
# Epoch 95/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2596 - accuracy: 0.9160 - val_loss: 0.3288 - val_accuracy: 0.8984
# Epoch 96/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2902 - accuracy: 0.9016 - val_loss: 0.2647 - val_accuracy: 0.9193
# Epoch 97/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.3068 - accuracy: 0.8993 - val_loss: 0.2490 - val_accuracy: 0.9115
# Epoch 98/750
# 67/67 [==============================] - 7s 103ms/step - loss: 0.2785 - accuracy: 0.9076 - val_loss: 0.2869 - val_accuracy: 0.8932
# Epoch 99/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2999 - accuracy: 0.9058 - val_loss: 0.2938 - val_accuracy: 0.9141
# Epoch 100/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2023 - accuracy: 0.9310 - val_loss: 0.3886 - val_accuracy: 0.9062
# Epoch 101/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2963 - accuracy: 0.9039 - val_loss: 0.3102 - val_accuracy: 0.9115
# Epoch 102/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2759 - accuracy: 0.9053 - val_loss: 0.3574 - val_accuracy: 0.8932
# Epoch 103/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2602 - accuracy: 0.9146 - val_loss: 0.2914 - val_accuracy: 0.9089
# Epoch 104/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2368 - accuracy: 0.9282 - val_loss: 0.2767 - val_accuracy: 0.9297
# Epoch 105/750
# 67/67 [==============================] - 0s 5ms/step - loss: 0.2670 - accuracy: 0.9142 - val_loss: 0.3002 - val_accuracy: 0.9036
# Epoch 106/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2635 - accuracy: 0.9146 - val_loss: 0.2599 - val_accuracy: 0.9219
# Epoch 107/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2546 - accuracy: 0.9179 - val_loss: 0.2850 - val_accuracy: 0.9245
# Epoch 108/750
# 67/67 [==============================] - 0s 5ms/step - loss: 0.2335 - accuracy: 0.9291 - val_loss: 0.2255 - val_accuracy: 0.9271
# Epoch 109/750
# 67/67 [==============================] - 0s 5ms/step - loss: 0.2642 - accuracy: 0.9123 - val_loss: 0.2458 - val_accuracy: 0.9089
# Epoch 110/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2319 - accuracy: 0.9156 - val_loss: 0.2196 - val_accuracy: 0.9375
# Epoch 111/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2614 - accuracy: 0.9240 - val_loss: 0.2425 - val_accuracy: 0.9349
# Epoch 112/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2619 - accuracy: 0.9170 - val_loss: 0.2461 - val_accuracy: 0.9271
# Epoch 113/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2511 - accuracy: 0.9216 - val_loss: 0.2997 - val_accuracy: 0.9141
# Epoch 114/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2349 - accuracy: 0.9207 - val_loss: 0.2207 - val_accuracy: 0.9297
# Epoch 115/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2520 - accuracy: 0.9156 - val_loss: 0.2901 - val_accuracy: 0.9141
# Epoch 116/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2638 - accuracy: 0.9184 - val_loss: 0.3385 - val_accuracy: 0.9036
# Epoch 117/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2141 - accuracy: 0.9254 - val_loss: 0.2462 - val_accuracy: 0.9297
# Epoch 118/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2522 - accuracy: 0.9277 - val_loss: 0.2069 - val_accuracy: 0.9349
# Epoch 119/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2479 - accuracy: 0.9212 - val_loss: 0.1950 - val_accuracy: 0.9349
# Epoch 120/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2213 - accuracy: 0.9268 - val_loss: 0.2306 - val_accuracy: 0.9297
# Epoch 121/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2121 - accuracy: 0.9347 - val_loss: 0.2078 - val_accuracy: 0.9375
# Epoch 122/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2461 - accuracy: 0.9207 - val_loss: 0.2895 - val_accuracy: 0.9349
# Epoch 123/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2257 - accuracy: 0.9286 - val_loss: 0.2434 - val_accuracy: 0.9297
# Epoch 124/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2397 - accuracy: 0.9296 - val_loss: 0.1831 - val_accuracy: 0.9375
# Epoch 125/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2281 - accuracy: 0.9296 - val_loss: 0.2778 - val_accuracy: 0.9245
# Epoch 126/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2151 - accuracy: 0.9296 - val_loss: 0.2836 - val_accuracy: 0.9167
# Epoch 127/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2482 - accuracy: 0.9226 - val_loss: 0.2149 - val_accuracy: 0.9193
# Epoch 128/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2211 - accuracy: 0.9310 - val_loss: 0.2284 - val_accuracy: 0.9375
# Epoch 129/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2406 - accuracy: 0.9277 - val_loss: 0.2181 - val_accuracy: 0.9297
# Epoch 130/750
# 67/67 [==============================] - 7s 103ms/step - loss: 0.2261 - accuracy: 0.9239 - val_loss: 0.2798 - val_accuracy: 0.9089
# Epoch 131/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2135 - accuracy: 0.9258 - val_loss: 0.2522 - val_accuracy: 0.9245
# Epoch 132/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1758 - accuracy: 0.9408 - val_loss: 0.2214 - val_accuracy: 0.9297
# Epoch 133/750
# 67/67 [==============================] - 0s 5ms/step - loss: 0.2462 - accuracy: 0.9235 - val_loss: 0.1788 - val_accuracy: 0.9427
# Epoch 134/750
# 67/67 [==============================] - 0s 5ms/step - loss: 0.1785 - accuracy: 0.9436 - val_loss: 0.1978 - val_accuracy: 0.9375
# Epoch 135/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2220 - accuracy: 0.9361 - val_loss: 0.2218 - val_accuracy: 0.9427
# Epoch 136/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2238 - accuracy: 0.9268 - val_loss: 0.2089 - val_accuracy: 0.9531
# Epoch 137/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2044 - accuracy: 0.9310 - val_loss: 0.2842 - val_accuracy: 0.9297
# Epoch 138/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2134 - accuracy: 0.9319 - val_loss: 0.1842 - val_accuracy: 0.9349
# Epoch 139/750
# 67/67 [==============================] - 0s 5ms/step - loss: 0.2304 - accuracy: 0.9235 - val_loss: 0.2212 - val_accuracy: 0.9219
# Epoch 140/750
# 67/67 [==============================] - 0s 5ms/step - loss: 0.2351 - accuracy: 0.9319 - val_loss: 0.2156 - val_accuracy: 0.9349
# Epoch 141/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1999 - accuracy: 0.9370 - val_loss: 0.2505 - val_accuracy: 0.9271
# Epoch 142/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1981 - accuracy: 0.9356 - val_loss: 0.2137 - val_accuracy: 0.9375
# Epoch 143/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1908 - accuracy: 0.9384 - val_loss: 0.2355 - val_accuracy: 0.9297
# Epoch 144/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1952 - accuracy: 0.9375 - val_loss: 0.2343 - val_accuracy: 0.9375
# Epoch 145/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1826 - accuracy: 0.9394 - val_loss: 0.2441 - val_accuracy: 0.9167
# Epoch 146/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1907 - accuracy: 0.9403 - val_loss: 0.2155 - val_accuracy: 0.9323
# Epoch 147/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1791 - accuracy: 0.9380 - val_loss: 0.1841 - val_accuracy: 0.9427
# Epoch 148/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1724 - accuracy: 0.9478 - val_loss: 0.2754 - val_accuracy: 0.9219
# Epoch 149/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1846 - accuracy: 0.9422 - val_loss: 0.3141 - val_accuracy: 0.9062
# Epoch 150/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2060 - accuracy: 0.9347 - val_loss: 0.2288 - val_accuracy: 0.9271
# Epoch 151/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2417 - accuracy: 0.9235 - val_loss: 0.2555 - val_accuracy: 0.9297
# Epoch 152/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1876 - accuracy: 0.9375 - val_loss: 0.3050 - val_accuracy: 0.9167
# Epoch 153/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1908 - accuracy: 0.9412 - val_loss: 0.2257 - val_accuracy: 0.9401
# Epoch 154/750
# 67/67 [==============================] - 0s 5ms/step - loss: 0.1780 - accuracy: 0.9403 - val_loss: 0.2293 - val_accuracy: 0.9297
# Epoch 155/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2065 - accuracy: 0.9356 - val_loss: 0.2937 - val_accuracy: 0.9297
# Epoch 156/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1730 - accuracy: 0.9422 - val_loss: 0.2453 - val_accuracy: 0.9375
# Epoch 157/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2098 - accuracy: 0.9277 - val_loss: 0.2462 - val_accuracy: 0.9141
# Epoch 158/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2174 - accuracy: 0.9305 - val_loss: 0.2221 - val_accuracy: 0.9271
# Epoch 159/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2118 - accuracy: 0.9314 - val_loss: 0.2602 - val_accuracy: 0.9297
# Epoch 160/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1717 - accuracy: 0.9501 - val_loss: 0.2709 - val_accuracy: 0.9245
# Epoch 161/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2001 - accuracy: 0.9370 - val_loss: 0.2547 - val_accuracy: 0.9167
# Epoch 162/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2038 - accuracy: 0.9286 - val_loss: 0.2605 - val_accuracy: 0.9167
# Epoch 163/750
# 67/67 [==============================] - 7s 103ms/step - loss: 0.1799 - accuracy: 0.9500 - val_loss: 0.2872 - val_accuracy: 0.9141
# Epoch 164/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2125 - accuracy: 0.9319 - val_loss: 0.2323 - val_accuracy: 0.9193
# Epoch 165/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1491 - accuracy: 0.9529 - val_loss: 0.2577 - val_accuracy: 0.9427
# Epoch 166/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1693 - accuracy: 0.9496 - val_loss: 0.2309 - val_accuracy: 0.9271
# Epoch 167/750
# 67/67 [==============================] - 0s 5ms/step - loss: 0.1622 - accuracy: 0.9440 - val_loss: 0.2331 - val_accuracy: 0.9323
# Epoch 168/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2231 - accuracy: 0.9272 - val_loss: 0.3178 - val_accuracy: 0.9245
# Epoch 169/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1539 - accuracy: 0.9501 - val_loss: 0.2815 - val_accuracy: 0.9297
# Epoch 170/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1554 - accuracy: 0.9501 - val_loss: 0.2500 - val_accuracy: 0.9323
# Epoch 171/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2118 - accuracy: 0.9268 - val_loss: 0.2102 - val_accuracy: 0.9323
# Epoch 172/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2001 - accuracy: 0.9338 - val_loss: 0.2637 - val_accuracy: 0.9323
# Epoch 173/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1885 - accuracy: 0.9361 - val_loss: 0.2348 - val_accuracy: 0.9323
# Epoch 174/750
# 67/67 [==============================] - 0s 5ms/step - loss: 0.1930 - accuracy: 0.9389 - val_loss: 0.2414 - val_accuracy: 0.9323
# Epoch 175/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1714 - accuracy: 0.9445 - val_loss: 0.2413 - val_accuracy: 0.9323
# Epoch 176/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1774 - accuracy: 0.9459 - val_loss: 0.2242 - val_accuracy: 0.9453
# Epoch 177/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2157 - accuracy: 0.9305 - val_loss: 0.1881 - val_accuracy: 0.9427
# Epoch 178/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1530 - accuracy: 0.9529 - val_loss: 0.2215 - val_accuracy: 0.9323
# Epoch 179/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1882 - accuracy: 0.9468 - val_loss: 0.2011 - val_accuracy: 0.9479
# Epoch 180/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1809 - accuracy: 0.9496 - val_loss: 0.2252 - val_accuracy: 0.9349
# Epoch 181/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1417 - accuracy: 0.9534 - val_loss: 0.2435 - val_accuracy: 0.9271
# Epoch 182/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1728 - accuracy: 0.9482 - val_loss: 0.2313 - val_accuracy: 0.9323
# Epoch 183/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1562 - accuracy: 0.9510 - val_loss: 0.2424 - val_accuracy: 0.9349
# Epoch 184/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1757 - accuracy: 0.9496 - val_loss: 0.2494 - val_accuracy: 0.9349
# Epoch 185/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1459 - accuracy: 0.9520 - val_loss: 0.2597 - val_accuracy: 0.9323
# Epoch 186/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1772 - accuracy: 0.9478 - val_loss: 0.2682 - val_accuracy: 0.9245
# Epoch 187/750
# 67/67 [==============================] - 0s 5ms/step - loss: 0.1620 - accuracy: 0.9482 - val_loss: 0.2738 - val_accuracy: 0.9297
# Epoch 188/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1733 - accuracy: 0.9394 - val_loss: 0.2681 - val_accuracy: 0.9297
# Epoch 189/750
# 67/67 [==============================] - 0s 5ms/step - loss: 0.1565 - accuracy: 0.9422 - val_loss: 0.1793 - val_accuracy: 0.9453
# Epoch 190/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1894 - accuracy: 0.9422 - val_loss: 0.2324 - val_accuracy: 0.9245
# Epoch 191/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1590 - accuracy: 0.9529 - val_loss: 0.2249 - val_accuracy: 0.9401
# Epoch 192/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1692 - accuracy: 0.9454 - val_loss: 0.2218 - val_accuracy: 0.9349
# Epoch 193/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1710 - accuracy: 0.9422 - val_loss: 0.1804 - val_accuracy: 0.9401
# Epoch 194/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2023 - accuracy: 0.9417 - val_loss: 0.2440 - val_accuracy: 0.9297
# Epoch 195/750
# 67/67 [==============================] - 7s 104ms/step - loss: 0.1624 - accuracy: 0.9482 - val_loss: 0.2677 - val_accuracy: 0.9089
# Epoch 196/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1497 - accuracy: 0.9543 - val_loss: 0.2317 - val_accuracy: 0.9401
# Epoch 197/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1321 - accuracy: 0.9566 - val_loss: 0.2888 - val_accuracy: 0.9297
# Epoch 198/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1413 - accuracy: 0.9580 - val_loss: 0.2211 - val_accuracy: 0.9375
# Epoch 199/750
# 67/67 [==============================] - 0s 5ms/step - loss: 0.1575 - accuracy: 0.9501 - val_loss: 0.2415 - val_accuracy: 0.9375
# Epoch 200/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1402 - accuracy: 0.9562 - val_loss: 0.2397 - val_accuracy: 0.9531
# Epoch 201/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1601 - accuracy: 0.9468 - val_loss: 0.2994 - val_accuracy: 0.9245
# Epoch 202/750
# 67/67 [==============================] - 0s 5ms/step - loss: 0.1834 - accuracy: 0.9450 - val_loss: 0.2627 - val_accuracy: 0.9219
# Epoch 203/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1667 - accuracy: 0.9464 - val_loss: 0.2070 - val_accuracy: 0.9297
# Epoch 204/750
# 67/67 [==============================] - 0s 5ms/step - loss: 0.1507 - accuracy: 0.9529 - val_loss: 0.1815 - val_accuracy: 0.9401
# Epoch 205/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1427 - accuracy: 0.9543 - val_loss: 0.2052 - val_accuracy: 0.9427
# Epoch 206/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1188 - accuracy: 0.9604 - val_loss: 0.2527 - val_accuracy: 0.9427
# Epoch 207/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1445 - accuracy: 0.9529 - val_loss: 0.2144 - val_accuracy: 0.9427
# Epoch 208/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1719 - accuracy: 0.9501 - val_loss: 0.2120 - val_accuracy: 0.9427
# Epoch 209/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1212 - accuracy: 0.9632 - val_loss: 0.2407 - val_accuracy: 0.9323
# Epoch 210/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1500 - accuracy: 0.9534 - val_loss: 0.2475 - val_accuracy: 0.9349
# Epoch 211/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1597 - accuracy: 0.9501 - val_loss: 0.1782 - val_accuracy: 0.9505
# Epoch 212/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1675 - accuracy: 0.9459 - val_loss: 0.2316 - val_accuracy: 0.9349
# Epoch 213/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1458 - accuracy: 0.9594 - val_loss: 0.2578 - val_accuracy: 0.9271
# Epoch 214/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1988 - accuracy: 0.9426 - val_loss: 0.2113 - val_accuracy: 0.9297
# Epoch 215/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1649 - accuracy: 0.9492 - val_loss: 0.1854 - val_accuracy: 0.9479
# Epoch 216/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1273 - accuracy: 0.9566 - val_loss: 0.2470 - val_accuracy: 0.9323
# Epoch 217/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1857 - accuracy: 0.9408 - val_loss: 0.2506 - val_accuracy: 0.9297
# Epoch 218/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1834 - accuracy: 0.9422 - val_loss: 0.1982 - val_accuracy: 0.9323
# Epoch 219/750
# 67/67 [==============================] - 0s 5ms/step - loss: 0.1324 - accuracy: 0.9534 - val_loss: 0.2250 - val_accuracy: 0.9297
# Epoch 220/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1592 - accuracy: 0.9520 - val_loss: 0.2445 - val_accuracy: 0.9401
# Epoch 221/750
# 67/67 [==============================] - 0s 5ms/step - loss: 0.1301 - accuracy: 0.9557 - val_loss: 0.2143 - val_accuracy: 0.9427
# Epoch 222/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1371 - accuracy: 0.9562 - val_loss: 0.1859 - val_accuracy: 0.9479
# Epoch 223/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1510 - accuracy: 0.9496 - val_loss: 0.2020 - val_accuracy: 0.9349
# Epoch 224/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1375 - accuracy: 0.9548 - val_loss: 0.1958 - val_accuracy: 0.9427
# Epoch 225/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1447 - accuracy: 0.9529 - val_loss: 0.2035 - val_accuracy: 0.9349
# Epoch 226/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1758 - accuracy: 0.9478 - val_loss: 0.2099 - val_accuracy: 0.9375
# Epoch 227/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1500 - accuracy: 0.9557 - val_loss: 0.2308 - val_accuracy: 0.9297
# Epoch 228/750
# 67/67 [==============================] - 7s 102ms/step - loss: 0.1680 - accuracy: 0.9454 - val_loss: 0.2427 - val_accuracy: 0.9271
# Epoch 229/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1417 - accuracy: 0.9608 - val_loss: 0.1921 - val_accuracy: 0.9505
# Epoch 230/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1676 - accuracy: 0.9450 - val_loss: 0.1935 - val_accuracy: 0.9427
# Epoch 231/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1667 - accuracy: 0.9506 - val_loss: 0.1853 - val_accuracy: 0.9349
# Epoch 232/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1387 - accuracy: 0.9571 - val_loss: 0.2311 - val_accuracy: 0.9375
# Epoch 233/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1829 - accuracy: 0.9431 - val_loss: 0.2383 - val_accuracy: 0.9297
# Epoch 234/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1506 - accuracy: 0.9538 - val_loss: 0.2334 - val_accuracy: 0.9297
# Epoch 235/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1639 - accuracy: 0.9468 - val_loss: 0.2236 - val_accuracy: 0.9349
# Epoch 236/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1281 - accuracy: 0.9622 - val_loss: 0.2216 - val_accuracy: 0.9401
# Epoch 237/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1765 - accuracy: 0.9510 - val_loss: 0.2453 - val_accuracy: 0.9349
# Epoch 238/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1622 - accuracy: 0.9515 - val_loss: 0.2385 - val_accuracy: 0.9401
# Epoch 239/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1367 - accuracy: 0.9566 - val_loss: 0.1876 - val_accuracy: 0.9453
# Epoch 240/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1428 - accuracy: 0.9538 - val_loss: 0.2791 - val_accuracy: 0.9245
# Epoch 241/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1223 - accuracy: 0.9636 - val_loss: 0.2235 - val_accuracy: 0.9349
# Epoch 242/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1530 - accuracy: 0.9487 - val_loss: 0.2496 - val_accuracy: 0.9349
# Epoch 243/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1458 - accuracy: 0.9571 - val_loss: 0.2520 - val_accuracy: 0.9323
# Epoch 244/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1403 - accuracy: 0.9543 - val_loss: 0.2126 - val_accuracy: 0.9375
# Epoch 245/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1390 - accuracy: 0.9552 - val_loss: 0.2447 - val_accuracy: 0.9297
# Epoch 246/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1561 - accuracy: 0.9538 - val_loss: 0.1851 - val_accuracy: 0.9323
# Epoch 247/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1169 - accuracy: 0.9632 - val_loss: 0.1843 - val_accuracy: 0.9349
# Epoch 248/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1345 - accuracy: 0.9543 - val_loss: 0.2002 - val_accuracy: 0.9401
# Epoch 249/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1463 - accuracy: 0.9576 - val_loss: 0.2226 - val_accuracy: 0.9297
# Epoch 250/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1229 - accuracy: 0.9627 - val_loss: 0.2464 - val_accuracy: 0.9297
# Epoch 251/750
# 67/67 [==============================] - 0s 5ms/step - loss: 0.1248 - accuracy: 0.9604 - val_loss: 0.2317 - val_accuracy: 0.9271
# Epoch 252/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1325 - accuracy: 0.9590 - val_loss: 0.2303 - val_accuracy: 0.9297
# Epoch 253/750
# 67/67 [==============================] - 0s 5ms/step - loss: 0.1355 - accuracy: 0.9590 - val_loss: 0.1943 - val_accuracy: 0.9401
# Epoch 254/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1597 - accuracy: 0.9538 - val_loss: 0.2689 - val_accuracy: 0.9323
# Epoch 255/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1608 - accuracy: 0.9548 - val_loss: 0.1757 - val_accuracy: 0.9427
# Epoch 256/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1391 - accuracy: 0.9576 - val_loss: 0.1967 - val_accuracy: 0.9375
# Epoch 257/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1378 - accuracy: 0.9571 - val_loss: 0.2019 - val_accuracy: 0.9375
# Epoch 258/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1303 - accuracy: 0.9613 - val_loss: 0.1824 - val_accuracy: 0.9427
# Epoch 259/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1215 - accuracy: 0.9608 - val_loss: 0.1985 - val_accuracy: 0.9427
# Epoch 260/750
# 67/67 [==============================] - 7s 102ms/step - loss: 0.1152 - accuracy: 0.9650 - val_loss: 0.2031 - val_accuracy: 0.9453
# Epoch 261/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0998 - accuracy: 0.9678 - val_loss: 0.3013 - val_accuracy: 0.9271
# Epoch 262/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1290 - accuracy: 0.9622 - val_loss: 0.2110 - val_accuracy: 0.9349
# Epoch 263/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1409 - accuracy: 0.9534 - val_loss: 0.1631 - val_accuracy: 0.9505
# Epoch 264/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1351 - accuracy: 0.9664 - val_loss: 0.2316 - val_accuracy: 0.9375
# Epoch 265/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1218 - accuracy: 0.9627 - val_loss: 0.1651 - val_accuracy: 0.9505
# Epoch 266/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0964 - accuracy: 0.9706 - val_loss: 0.1763 - val_accuracy: 0.9427
# Epoch 267/750
# 67/67 [==============================] - 0s 5ms/step - loss: 0.1490 - accuracy: 0.9534 - val_loss: 0.1962 - val_accuracy: 0.9479
# Epoch 268/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1435 - accuracy: 0.9580 - val_loss: 0.2473 - val_accuracy: 0.9271
# Epoch 269/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1334 - accuracy: 0.9562 - val_loss: 0.2675 - val_accuracy: 0.9271
# Epoch 270/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0907 - accuracy: 0.9697 - val_loss: 0.2391 - val_accuracy: 0.9323
# Epoch 271/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1513 - accuracy: 0.9571 - val_loss: 0.2113 - val_accuracy: 0.9297
# Epoch 272/750
# 67/67 [==============================] - 0s 5ms/step - loss: 0.1623 - accuracy: 0.9510 - val_loss: 0.2895 - val_accuracy: 0.9297
# Epoch 273/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1356 - accuracy: 0.9608 - val_loss: 0.3331 - val_accuracy: 0.9141
# Epoch 274/750
# 67/67 [==============================] - 0s 5ms/step - loss: 0.1116 - accuracy: 0.9701 - val_loss: 0.1775 - val_accuracy: 0.9427
# Epoch 275/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1400 - accuracy: 0.9590 - val_loss: 0.1893 - val_accuracy: 0.9349
# Epoch 276/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0953 - accuracy: 0.9683 - val_loss: 0.2128 - val_accuracy: 0.9427
# Epoch 277/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1437 - accuracy: 0.9562 - val_loss: 0.2185 - val_accuracy: 0.9297
# Epoch 278/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1421 - accuracy: 0.9562 - val_loss: 0.1916 - val_accuracy: 0.9323
# Epoch 279/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1355 - accuracy: 0.9566 - val_loss: 0.2459 - val_accuracy: 0.9297
# Epoch 280/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1426 - accuracy: 0.9571 - val_loss: 0.2463 - val_accuracy: 0.9323
# Epoch 281/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1476 - accuracy: 0.9585 - val_loss: 0.2673 - val_accuracy: 0.9297
# Epoch 282/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1357 - accuracy: 0.9576 - val_loss: 0.2416 - val_accuracy: 0.9297
# Epoch 283/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1335 - accuracy: 0.9548 - val_loss: 0.2062 - val_accuracy: 0.9349
# Epoch 284/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1484 - accuracy: 0.9562 - val_loss: 0.1974 - val_accuracy: 0.9375
# Epoch 285/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1153 - accuracy: 0.9688 - val_loss: 0.1823 - val_accuracy: 0.9401
# Epoch 286/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1410 - accuracy: 0.9613 - val_loss: 0.1792 - val_accuracy: 0.9505
# Epoch 287/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1103 - accuracy: 0.9627 - val_loss: 0.2638 - val_accuracy: 0.9271
# Epoch 288/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1207 - accuracy: 0.9585 - val_loss: 0.2178 - val_accuracy: 0.9349
# Epoch 289/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1210 - accuracy: 0.9566 - val_loss: 0.2670 - val_accuracy: 0.9323
# Epoch 290/750
# 67/67 [==============================] - 0s 5ms/step - loss: 0.1286 - accuracy: 0.9618 - val_loss: 0.2513 - val_accuracy: 0.9297
# Epoch 291/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1409 - accuracy: 0.9557 - val_loss: 0.2657 - val_accuracy: 0.9349
# Epoch 292/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1436 - accuracy: 0.9599 - val_loss: 0.1919 - val_accuracy: 0.9375
# Epoch 293/750
# 67/67 [==============================] - 7s 100ms/step - loss: 0.1207 - accuracy: 0.9627 - val_loss: 0.2267 - val_accuracy: 0.9427
# Epoch 294/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1169 - accuracy: 0.9660 - val_loss: 0.1892 - val_accuracy: 0.9531
# Epoch 295/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1341 - accuracy: 0.9599 - val_loss: 0.1963 - val_accuracy: 0.9401
# Epoch 296/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1110 - accuracy: 0.9706 - val_loss: 0.2071 - val_accuracy: 0.9427
# Epoch 297/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1224 - accuracy: 0.9613 - val_loss: 0.1984 - val_accuracy: 0.9349
# Epoch 298/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1205 - accuracy: 0.9622 - val_loss: 0.2113 - val_accuracy: 0.9401
# Epoch 299/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1106 - accuracy: 0.9678 - val_loss: 0.1636 - val_accuracy: 0.9505
# Epoch 300/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1097 - accuracy: 0.9650 - val_loss: 0.2031 - val_accuracy: 0.9531
# Epoch 301/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1200 - accuracy: 0.9613 - val_loss: 0.2010 - val_accuracy: 0.9375
# Epoch 302/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1239 - accuracy: 0.9580 - val_loss: 0.2997 - val_accuracy: 0.9219
# Epoch 303/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1443 - accuracy: 0.9608 - val_loss: 0.3091 - val_accuracy: 0.9167
# Epoch 304/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1239 - accuracy: 0.9618 - val_loss: 0.2470 - val_accuracy: 0.9323
# Epoch 305/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0950 - accuracy: 0.9701 - val_loss: 0.2098 - val_accuracy: 0.9479
# Epoch 306/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1312 - accuracy: 0.9632 - val_loss: 0.2940 - val_accuracy: 0.9245
# Epoch 307/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1170 - accuracy: 0.9618 - val_loss: 0.2054 - val_accuracy: 0.9453
# Epoch 308/750
# 67/67 [==============================] - 0s 5ms/step - loss: 0.1282 - accuracy: 0.9627 - val_loss: 0.2534 - val_accuracy: 0.9349
# Epoch 309/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1281 - accuracy: 0.9641 - val_loss: 0.2142 - val_accuracy: 0.9427
# Epoch 310/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1010 - accuracy: 0.9678 - val_loss: 0.1999 - val_accuracy: 0.9479
# Epoch 311/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1074 - accuracy: 0.9669 - val_loss: 0.2184 - val_accuracy: 0.9323
# Epoch 312/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1209 - accuracy: 0.9632 - val_loss: 0.1706 - val_accuracy: 0.9375
# Epoch 313/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1125 - accuracy: 0.9664 - val_loss: 0.2169 - val_accuracy: 0.9427
# Epoch 314/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1026 - accuracy: 0.9669 - val_loss: 0.2282 - val_accuracy: 0.9323
# Epoch 315/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0862 - accuracy: 0.9725 - val_loss: 0.2586 - val_accuracy: 0.9427
# Epoch 316/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0964 - accuracy: 0.9683 - val_loss: 0.2764 - val_accuracy: 0.9401
# Epoch 317/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1260 - accuracy: 0.9618 - val_loss: 0.2422 - val_accuracy: 0.9349
# Epoch 318/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1265 - accuracy: 0.9632 - val_loss: 0.2240 - val_accuracy: 0.9401
# Epoch 319/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1467 - accuracy: 0.9580 - val_loss: 0.2290 - val_accuracy: 0.9479
# Epoch 320/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1195 - accuracy: 0.9664 - val_loss: 0.1835 - val_accuracy: 0.9401
# Epoch 321/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1044 - accuracy: 0.9674 - val_loss: 0.2367 - val_accuracy: 0.9245
# Epoch 322/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0986 - accuracy: 0.9632 - val_loss: 0.2661 - val_accuracy: 0.9375
# Epoch 323/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1409 - accuracy: 0.9604 - val_loss: 0.2137 - val_accuracy: 0.9401
# Epoch 324/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1080 - accuracy: 0.9720 - val_loss: 0.2383 - val_accuracy: 0.9401
# Epoch 325/750
# 67/67 [==============================] - 7s 103ms/step - loss: 0.1062 - accuracy: 0.9650 - val_loss: 0.2494 - val_accuracy: 0.9401
# Epoch 326/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1431 - accuracy: 0.9566 - val_loss: 0.2807 - val_accuracy: 0.9349
# Epoch 327/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1202 - accuracy: 0.9674 - val_loss: 0.2758 - val_accuracy: 0.9323
# Epoch 328/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0837 - accuracy: 0.9762 - val_loss: 0.2388 - val_accuracy: 0.9401
# Epoch 329/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1192 - accuracy: 0.9650 - val_loss: 0.2402 - val_accuracy: 0.9297
# Epoch 330/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1509 - accuracy: 0.9622 - val_loss: 0.2316 - val_accuracy: 0.9375
# Epoch 331/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1421 - accuracy: 0.9585 - val_loss: 0.2089 - val_accuracy: 0.9349
# Epoch 332/750
# ...
# Epoch 640/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1000 - accuracy: 0.9725 - val_loss: 0.2580 - val_accuracy: 0.9323
# Epoch 641/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0902 - accuracy: 0.9743 - val_loss: 0.2246 - val_accuracy: 0.9323
# Epoch 642/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0730 - accuracy: 0.9799 - val_loss: 0.2113 - val_accuracy: 0.9557
# Epoch 643/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0797 - accuracy: 0.9781 - val_loss: 0.2180 - val_accuracy: 0.9453
# Epoch 644/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0740 - accuracy: 0.9795 - val_loss: 0.2193 - val_accuracy: 0.9427
# Epoch 645/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0759 - accuracy: 0.9790 - val_loss: 0.2282 - val_accuracy: 0.9401
# Epoch 646/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0589 - accuracy: 0.9823 - val_loss: 0.2454 - val_accuracy: 0.9427
# Epoch 647/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0748 - accuracy: 0.9753 - val_loss: 0.2378 - val_accuracy: 0.9297
# Epoch 648/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1026 - accuracy: 0.9743 - val_loss: 0.2476 - val_accuracy: 0.9271
# Epoch 649/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0608 - accuracy: 0.9799 - val_loss: 0.2297 - val_accuracy: 0.9323
# Epoch 650/750
# 67/67 [==============================] - 7s 101ms/step - loss: 0.0771 - accuracy: 0.9795 - val_loss: 0.2615 - val_accuracy: 0.9453
# Epoch 651/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0790 - accuracy: 0.9767 - val_loss: 0.1953 - val_accuracy: 0.9453
# Epoch 652/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0997 - accuracy: 0.9757 - val_loss: 0.2051 - val_accuracy: 0.9375
# Epoch 653/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0777 - accuracy: 0.9795 - val_loss: 0.1987 - val_accuracy: 0.9479
# Epoch 654/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0752 - accuracy: 0.9832 - val_loss: 0.2066 - val_accuracy: 0.9375
# Epoch 655/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0786 - accuracy: 0.9795 - val_loss: 0.2178 - val_accuracy: 0.9453
# Epoch 656/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1137 - accuracy: 0.9660 - val_loss: 0.2375 - val_accuracy: 0.9375
# Epoch 657/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1007 - accuracy: 0.9715 - val_loss: 0.2490 - val_accuracy: 0.9349
# Epoch 658/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0710 - accuracy: 0.9767 - val_loss: 0.1992 - val_accuracy: 0.9479
# Epoch 659/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0622 - accuracy: 0.9804 - val_loss: 0.2039 - val_accuracy: 0.9505
# Epoch 660/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0828 - accuracy: 0.9771 - val_loss: 0.1810 - val_accuracy: 0.9479
# Epoch 661/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0642 - accuracy: 0.9790 - val_loss: 0.2268 - val_accuracy: 0.9297
# Epoch 662/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0902 - accuracy: 0.9711 - val_loss: 0.2148 - val_accuracy: 0.9479
# Epoch 663/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0731 - accuracy: 0.9757 - val_loss: 0.2051 - val_accuracy: 0.9323
# Epoch 664/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0825 - accuracy: 0.9771 - val_loss: 0.2388 - val_accuracy: 0.9375
# Epoch 665/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0697 - accuracy: 0.9790 - val_loss: 0.2316 - val_accuracy: 0.9427
# Epoch 666/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0995 - accuracy: 0.9748 - val_loss: 0.2656 - val_accuracy: 0.9401
# Epoch 667/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1105 - accuracy: 0.9729 - val_loss: 0.3017 - val_accuracy: 0.9297
# Epoch 668/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1026 - accuracy: 0.9711 - val_loss: 0.2324 - val_accuracy: 0.9479
# Epoch 669/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0907 - accuracy: 0.9804 - val_loss: 0.2375 - val_accuracy: 0.9349
# Epoch 670/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0755 - accuracy: 0.9762 - val_loss: 0.2020 - val_accuracy: 0.9427
# Epoch 671/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0606 - accuracy: 0.9799 - val_loss: 0.2144 - val_accuracy: 0.9427
# Epoch 672/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0701 - accuracy: 0.9790 - val_loss: 0.2460 - val_accuracy: 0.9453
# Epoch 673/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0757 - accuracy: 0.9813 - val_loss: 0.2495 - val_accuracy: 0.9245
# Epoch 674/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0964 - accuracy: 0.9734 - val_loss: 0.2614 - val_accuracy: 0.9323
# Epoch 675/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0503 - accuracy: 0.9874 - val_loss: 0.2844 - val_accuracy: 0.9427
# Epoch 676/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0482 - accuracy: 0.9823 - val_loss: 0.2117 - val_accuracy: 0.9479
# Epoch 677/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0737 - accuracy: 0.9818 - val_loss: 0.2541 - val_accuracy: 0.9401
# Epoch 678/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0772 - accuracy: 0.9776 - val_loss: 0.2075 - val_accuracy: 0.9349
# Epoch 679/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0789 - accuracy: 0.9767 - val_loss: 0.2213 - val_accuracy: 0.9453
# Epoch 680/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0564 - accuracy: 0.9841 - val_loss: 0.2211 - val_accuracy: 0.9375
# Epoch 681/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0706 - accuracy: 0.9781 - val_loss: 0.2659 - val_accuracy: 0.9271
# Epoch 682/750
# 67/67 [==============================] - 7s 99ms/step - loss: 0.0748 - accuracy: 0.9767 - val_loss: 0.2965 - val_accuracy: 0.9375
# Epoch 683/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0677 - accuracy: 0.9809 - val_loss: 0.3037 - val_accuracy: 0.9349
# Epoch 684/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0747 - accuracy: 0.9790 - val_loss: 0.2817 - val_accuracy: 0.9323
# Epoch 685/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0627 - accuracy: 0.9813 - val_loss: 0.3046 - val_accuracy: 0.9349
# Epoch 686/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1114 - accuracy: 0.9715 - val_loss: 0.3103 - val_accuracy: 0.9323
# Epoch 687/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0740 - accuracy: 0.9781 - val_loss: 0.2605 - val_accuracy: 0.9401
# Epoch 688/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0808 - accuracy: 0.9790 - val_loss: 0.2325 - val_accuracy: 0.9349
# Epoch 689/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0638 - accuracy: 0.9855 - val_loss: 0.2629 - val_accuracy: 0.9349
# Epoch 690/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0683 - accuracy: 0.9781 - val_loss: 0.2243 - val_accuracy: 0.9323
# Epoch 691/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0819 - accuracy: 0.9767 - val_loss: 0.2661 - val_accuracy: 0.9271
# Epoch 692/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0708 - accuracy: 0.9762 - val_loss: 0.2974 - val_accuracy: 0.9349
# Epoch 693/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0777 - accuracy: 0.9813 - val_loss: 0.3382 - val_accuracy: 0.9219
# Epoch 694/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0907 - accuracy: 0.9767 - val_loss: 0.3137 - val_accuracy: 0.9349
# Epoch 695/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0515 - accuracy: 0.9851 - val_loss: 0.2885 - val_accuracy: 0.9245
# Epoch 696/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1080 - accuracy: 0.9729 - val_loss: 0.3462 - val_accuracy: 0.9323
# Epoch 697/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0857 - accuracy: 0.9753 - val_loss: 0.3320 - val_accuracy: 0.9323
# Epoch 698/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0691 - accuracy: 0.9827 - val_loss: 0.2998 - val_accuracy: 0.9271
# Epoch 699/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0836 - accuracy: 0.9799 - val_loss: 0.3256 - val_accuracy: 0.9297
# Epoch 700/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0833 - accuracy: 0.9757 - val_loss: 0.3035 - val_accuracy: 0.9297
# Epoch 701/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0816 - accuracy: 0.9734 - val_loss: 0.2656 - val_accuracy: 0.9479
# Epoch 702/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0942 - accuracy: 0.9776 - val_loss: 0.4100 - val_accuracy: 0.8932
# Epoch 703/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1457 - accuracy: 0.9664 - val_loss: 0.2844 - val_accuracy: 0.9375
# Epoch 704/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0966 - accuracy: 0.9701 - val_loss: 0.2873 - val_accuracy: 0.9453
# Epoch 705/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0683 - accuracy: 0.9785 - val_loss: 0.2587 - val_accuracy: 0.9375
# Epoch 706/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0739 - accuracy: 0.9781 - val_loss: 0.2874 - val_accuracy: 0.9375
# Epoch 707/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0532 - accuracy: 0.9837 - val_loss: 0.2651 - val_accuracy: 0.9323
# Epoch 708/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0872 - accuracy: 0.9767 - val_loss: 0.3097 - val_accuracy: 0.9323
# Epoch 709/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0743 - accuracy: 0.9795 - val_loss: 0.3924 - val_accuracy: 0.9193
# Epoch 710/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1028 - accuracy: 0.9743 - val_loss: 0.3163 - val_accuracy: 0.9323
# Epoch 711/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0685 - accuracy: 0.9813 - val_loss: 0.2860 - val_accuracy: 0.9401
# Epoch 712/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0647 - accuracy: 0.9855 - val_loss: 0.2471 - val_accuracy: 0.9505
# Epoch 713/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0808 - accuracy: 0.9827 - val_loss: 0.3002 - val_accuracy: 0.9323
# Epoch 714/750
# 67/67 [==============================] - 1s 8ms/step - loss: 0.0592 - accuracy: 0.9841 - val_loss: 0.2945 - val_accuracy: 0.9245
# Epoch 715/750
# 67/67 [==============================] - 7s 103ms/step - loss: 0.0562 - accuracy: 0.9809 - val_loss: 0.3054 - val_accuracy: 0.9375
# Epoch 716/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0824 - accuracy: 0.9799 - val_loss: 0.3502 - val_accuracy: 0.9323
# Epoch 717/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0780 - accuracy: 0.9799 - val_loss: 0.2031 - val_accuracy: 0.9401
# Epoch 718/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0931 - accuracy: 0.9776 - val_loss: 0.2866 - val_accuracy: 0.9219
# Epoch 719/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0838 - accuracy: 0.9762 - val_loss: 0.2945 - val_accuracy: 0.9453
# Epoch 720/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0859 - accuracy: 0.9771 - val_loss: 0.3041 - val_accuracy: 0.9375
# Epoch 721/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0964 - accuracy: 0.9771 - val_loss: 0.3226 - val_accuracy: 0.9427
# Epoch 722/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0717 - accuracy: 0.9785 - val_loss: 0.3006 - val_accuracy: 0.9245
# Epoch 723/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0826 - accuracy: 0.9776 - val_loss: 0.3975 - val_accuracy: 0.9193
# Epoch 724/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0922 - accuracy: 0.9739 - val_loss: 0.3538 - val_accuracy: 0.9271
# Epoch 725/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0886 - accuracy: 0.9785 - val_loss: 0.4496 - val_accuracy: 0.9167
# Epoch 726/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0622 - accuracy: 0.9804 - val_loss: 0.3563 - val_accuracy: 0.9349
# Epoch 727/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0600 - accuracy: 0.9832 - val_loss: 0.2992 - val_accuracy: 0.9427
# Epoch 728/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0663 - accuracy: 0.9790 - val_loss: 0.2954 - val_accuracy: 0.9375
# Epoch 729/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0648 - accuracy: 0.9827 - val_loss: 0.2249 - val_accuracy: 0.9479
# Epoch 730/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0792 - accuracy: 0.9781 - val_loss: 0.3600 - val_accuracy: 0.9219
# Epoch 731/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0772 - accuracy: 0.9785 - val_loss: 0.2608 - val_accuracy: 0.9375
# Epoch 732/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0624 - accuracy: 0.9837 - val_loss: 0.3683 - val_accuracy: 0.9297
# Epoch 733/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0969 - accuracy: 0.9771 - val_loss: 0.2936 - val_accuracy: 0.9375
# Epoch 734/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0998 - accuracy: 0.9734 - val_loss: 0.2140 - val_accuracy: 0.9505
# Epoch 735/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0718 - accuracy: 0.9748 - val_loss: 0.2298 - val_accuracy: 0.9479
# Epoch 736/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0691 - accuracy: 0.9795 - val_loss: 0.2592 - val_accuracy: 0.9323
# Epoch 737/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0739 - accuracy: 0.9790 - val_loss: 0.2964 - val_accuracy: 0.9453
# Epoch 738/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1128 - accuracy: 0.9715 - val_loss: 0.2854 - val_accuracy: 0.9297
# Epoch 739/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0607 - accuracy: 0.9818 - val_loss: 0.2399 - val_accuracy: 0.9401
# Epoch 740/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0774 - accuracy: 0.9757 - val_loss: 0.2834 - val_accuracy: 0.9401
# Epoch 741/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0853 - accuracy: 0.9762 - val_loss: 0.3577 - val_accuracy: 0.9245
# Epoch 742/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0748 - accuracy: 0.9799 - val_loss: 0.2757 - val_accuracy: 0.9453
# Epoch 743/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0684 - accuracy: 0.9813 - val_loss: 0.2263 - val_accuracy: 0.9427
# Epoch 744/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0639 - accuracy: 0.9846 - val_loss: 0.2435 - val_accuracy: 0.9297
# Epoch 745/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0797 - accuracy: 0.9785 - val_loss: 0.2194 - val_accuracy: 0.9453
# Epoch 746/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0783 - accuracy: 0.9823 - val_loss: 0.2084 - val_accuracy: 0.9531
# Epoch 747/750
# 67/67 [==============================] - 7s 101ms/step - loss: 0.0637 - accuracy: 0.9799 - val_loss: 0.2442 - val_accuracy: 0.9453
# Epoch 748/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0618 - accuracy: 0.9781 - val_loss: 0.2219 - val_accuracy: 0.9453
# Epoch 749/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0514 - accuracy: 0.9865 - val_loss: 0.2303 - val_accuracy: 0.9505
# Epoch 750/750
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0778 - accuracy: 0.9799 - val_loss: 0.2367 - val_accuracy: 0.9479

# %%
# notification that training is complete
# from send_text import send_text
# send_text()

# %%
# %tensorboard --logdir logs/fit --port 1975
# Out:
# Reusing TensorBoard on port 1975 (pid 22112), started 0:12:06 ago. (Use '!kill 22112' to kill it.)
#       <iframe id="tensorboard-frame-f6884bbc9c6cd17e" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-f6884bbc9c6cd17e");
#           const url = new URL("/", window.location);
#           const port = 1975;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# !taskkill /F /PID 14204
# Out:
# ERROR: The process "14204" not found.

# %%
model.save('exp2.mdl')
# Out:
# WARNING:tensorflow:From c:\users\kitthekat\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From c:\users\kitthekat\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: exp2.mdl\assets

# %%
from tensorflow import keras
model = keras.models.load_model('exp2.mdl')

# %%
model.load_weights("tmp/checkpoints/weights.732-0.17.hdf5")

# %% [markdown]
# ### Check accuracy on validation dataset

# %%
valid_t = tfds.as_numpy(valid)

# %%
valid_t = list(map(lambda x: (x[0].reshape(-1, 32, 32, 3), x[1]), valid_t))

# %%
valid_t = list(zip(*valid_t))

# %%
preds = list(map(lambda x: np.argmax(model.predict(x), axis=-1), valid_t[0]))
# Out:
# WARNING:tensorflow:From <ipython-input-25-b1ec049580e7>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(valid_t[1], preds)
# Out:
# 0.9464852607709751
